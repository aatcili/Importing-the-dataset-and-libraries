# %% [markdown]
# ### Lets start with importing the libraries

# %%
import numpy as np  # we import the library and to not write the long name, we shorten it as np
import pandas as pd  # we import the library and to not write the long name, we shorten it as pd
import matplotlib.pyplot as plt  # we import the library and to not write the long name, we shorten it as plt

# %% [markdown]
# ### Here is the time for Importing the Data

# %%
# to read a data, we use read function from pandas
dataset = pd.read_csv("city.csv")
dataset.head()  # head function give us the first 5 line
# Out:
#           city state
# 0   Pleasanton    CA
# 1  Santa Clara    CA
# 2       Denver    CO
# 3     Portland    OR
# 4       Tucson    AZ

# %%
dataFrame = pd.read_csv("Titanic_train.csv")
dataFrame.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Now its time to decide what is informative features and what is the result for us.

# %%
X= dataFrame.iloc[:,2:]
y= dataFrame.iloc[:,1:2]

# %%
X.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
y.tail() # tail function give us the last 5 lines of dataset
# Out:
#      Survived
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0

# %% [markdown]
# ### Taking care of missing Data

# %%
dataFrame.isnull().sum()  # we see which columns has null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,8))
sns.heatmap(dataFrame.isnull(), cmap= "viridis")

# %%
dataFrame.drop("Cabin", axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ###  Splittind the data into the Training set  an Test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#      Pclass                                          Name     Sex   Age  \
# 381       3                   Nakid, Miss. Maria ("Mary")  female   1.0
# 473       2  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.0
# 257       1                          Cherry, Miss. Gladys  female  30.0
# 310       1                Hays, Miss. Margaret Bechstein  female  24.0
# 520       1                         Perreault, Miss. Anne  female  30.0
# ..      ...                                           ...     ...   ...
# 105       3                         Mionoff, Mr. Stoytcho    male  28.0
# 118       1                      Baxter, Mr. Quigg Edmond    male  24.0
# 219       2                            Harris, Mr. Walter    male  30.0
# 533       3        Peter, Mrs. Catherine (Catherine Rizk)  female   NaN
# 597       3                           Johnson, Mr. Alfred    male  49.0
#
#      SibSp  Parch           Ticket      Fare    Cabin Embarked
# ...

# %%
X_test
# Out:
#      Pclass                                               Name     Sex   Age  \
# 189       3                                Turcin, Mr. Stjepan    male  36.0
# 674       2                         Watson, Mr. Ennis Hastings    male   NaN
# 44        3                      Devaney, Miss. Margaret Delia  female  19.0
# 380       1                              Bidois, Miss. Rosalie  female  42.0
# 33        2                              Wheadon, Mr. Edward H    male  66.0
# ..      ...                                                ...     ...   ...
# 504       1                              Maioni, Miss. Roberta  female  16.0
# 676       3                      Sawyer, Mr. Frederick Charles    male  24.5
# 842       1                            Serepeca, Miss. Augusta  female  30.0
# 14        3               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 670       2  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0
#
# ...

# %%
 y_train.shape
# Out:
# (623, 1)

# %%
y_test.shape
# Out:
# (268, 1)
